# %%
import cv2

# %%
img = cv2.imread('./字幕截图.jpg')

# %%
type(img)
# Out:
# NoneType

# %%
from PIL import Image

# %%
Image.open('./字幕截图.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1643x736 at 0x2529950ED68>
